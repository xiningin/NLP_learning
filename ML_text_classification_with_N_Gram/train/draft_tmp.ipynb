# %%
import numpy as np

a = np.array([0,1,2]*3)
a = a.reshape(3 , -1)
a
# Out:
# array([[0, 1, 2],
#        [0, 1, 2],
#        [0, 1, 2]])

# %%
tmp = np.exp(-a)
res = 1 / (1 + tmp)
res
# Out:
# array([[0.5       , 0.73105858, 0.88079708],
#        [0.5       , 0.73105858, 0.88079708],
#        [0.5       , 0.73105858, 0.88079708]])

# %%
tmp = np.exp(-(a-a.mean(axis=1 , keepdims=True)))
res = 1 / (1 + tmp)
res
# Out:
# array([[0.26894142, 0.5       , 0.73105858],
#        [0.26894142, 0.5       , 0.73105858],
#        [0.26894142, 0.5       , 0.73105858]])

# %%
for i in range(2):
    print(i)
# Out:
# 0
# 1

# %%
import random
index = range(4)
print(random.sample(index , 1)[0])
# Out:
# 1

# %%
list1 = [[121,3] , [111,5]]
list2 = [[154,8]]

list1 + list2
# Out:
# [[121, 3], [111, 5], [154, 8]]

# %%
from tqdm import tqdm
for item in tqdm(list1 + list2):
    print(item)
# Out:
# 100%|██████████| 3/3 [00:00<00:00, 3053.36it/s]
# [121, 3]
# [111, 5]
# [154, 8]

# %%
list(range(5))
# Out:
# [0, 1, 2, 3, 4]

# %%
import matplotlib.pyplot as plt
 
# 月份
x1 = ['2017-01', '2017-02', '2017-03', '2017-04', '2017-05', '2017-06', '2017-07', '2017-08',
      '2017-09', '2017-10', '2017-11', '2017-12']
 
# 体重
y1 = [86, 85, 84, 80, 75, 70, 70, 74, 78, 70, 74, 80]

# 设置画布大小
plt.figure(figsize=(16, 4))
 
# 标题
plt.title("my weight")
 
# 数据
plt.plot(x1, y1, label='weight changes', linewidth=3, color='r', markersize=20)
 
# 横坐标描述
plt.xlabel('month')
 
# 纵坐标描述
plt.ylabel('weight')
 
# 设置数字标签
for a, b in zip(x1, y1):
    plt.text(a, b, b, ha='center', va='bottom', fontsize=20)
 
plt.legend()
plt.show()

# %%
a = 1.2144848848
'%.2f'%a
# Out:
# '1.21'

# %%
import numpy as np

a = np.array([[1,1],[0.5,-0.22]])
np.sqrt(np.abs(a))
# Out:
# array([[1.        , 1.        ],
#        [0.70710678, 0.46904158]])

# %%
from datetime import datetime
datetime.now().strftime('%Y-%m-%d %H:%M')
# Out:
# '2023-03-08 15:22'

# %%
import numpy as np

a = np.array([['123',0],['543124',1],['123',0]])
a1 = a[a[:,1] == '0']
a2 = a[a[:,1] != '0']

np.vstack((a1,a2))
# Out:
# array([['123', '0'],
#        ['123', '0'],
#        ['543124', '1']], dtype='<U11')

# %%
a = np.array([
    [1,2,3],
    [2,4,6],
    [1,7,4]
])

b = [1,2]

a[b]
# Out:
# array([[2, 4, 6],
#        [1, 7, 4]])
